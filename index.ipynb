# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep

# %%
# driver = webdriver.Firefox(executable_path = '/usr/local/bin/geckodriver')
driver = webdriver.Chrome(executable_path = '/usr/local/bin/chromedriver')  # Optional argument, if not specified will search path.

# %%
driver.get("https://www.netflix.com/")
login = driver.find_element_by_css_selector(".authLinks")
login.click()

# %%
element = driver.find_element_by_name("userLoginId")
element.clear()
element.send_keys("johndoe@gmail.com")
element2 = driver.find_element_by_name("password")
element2.clear()
element2.send_keys("qwertyuiop")

# %%
submit = driver.find_element_by_css_selector(".btn.login-button.btn-submit.btn-small")
submit.click()

# %%
# change profile
# driver.find_element_by_css_selector('.profile-name[text()="Sachit"]').click()
sleep(3)
driver.find_element_by_xpath("//span[@class='profile-name' and text()='Sachit']").click()

# %%
def searchMechanism(keyword, inputClose = True):
    if(inputClose):
        searchButton = driver.find_element_by_css_selector(".searchTab")
        searchButton.click()
    searchInput = driver.find_element_by_name("searchInput")
    searchInput.clear()
    searchInput.send_keys(keyword)

# %%
def search(keyword):
    driver.get("https://www.netflix.com/")
    sleep(5)
    try:
        searchInput = driver.find_element_by_name("searchInput")
    except Exception as ex:
        if(ex.__class__.__name__ == 'NoSuchElementException'):
            searchMechanism(keyword)
    finally:
        searchMechanism(keyword, False)
        sleep(3)
        firstResult = driver.find_element_by_css_selector(".slider-refocus")
        firstResult.click()

# %%
def episodeInfo(prefix, text): 
    epiArr = text.split(': ')
    season = int(epiArr[0])
    return {'seasonInfo': f'{prefix} {season}', 'season': season, 'episode': epiArr[1]}

# %%
def showText(text):
    showArray = text.split(': Part ')
    if(len(showArray) > 1):
        print(showArray)
        return showArray[0], episodeInfo('Part', showArray[1])
    showArray = text.split(': Season ')
    if(len(showArray) > 1):
        print(showArray)
        return showArray[0], episodeInfo('Season', showArray[1])
    return text, False

# %%
def moveToLast():
    sleep(5)
    player = driver.find_element_by_css_selector(".AkiraPlayer")
    sleep(5)
    player.click()
    e = driver.find_element_by_css_selector(".scrubber-bar")
    location = e.location
    size = e.size

    x = size['width'] + location['x']
    y = int(size['height']/2) + location['y']

    sleep(5)
    player.click()
    actions = webdriver.ActionChains(driver)
    actions.move_to_element_with_offset(player, x, y).click().perform()

# %%
def findEpisode(episodeName, expandedList = False):
    try:
        episode = driver.find_element_by_xpath(f'//span[@class="titleCard-title_text" and text()="{episodeName}"]')
        episode.click()
    except Exception as ex:
        if(ex.__class__.__name__ == 'NoSuchElementException'):
            if not expandedList:
                driver.find_element_by_css_selector(".section-expandButton").click()
            findEpisode(episodeName, True)

# %%
def performAction(searchKey):
    try:
        show, seriesInfo = showText(searchKey)
        print(show, seriesInfo)
        search(show)
        if seriesInfo:
            sleep(3)
            dropdown = driver.find_element_by_css_selector(".dropdown-toggle")
            seasonInfo = seriesInfo['seasonInfo']
            currentSE = dropdown.text
            print(currentSE, seasonInfo)
            if currentSE != seasonInfo:
                dropdown.click()
                driver.find_element_by_xpath(f'//li[@data-uia="dropdown-menu-item" and text()="{seasonInfo}"]').click()
            findEpisode(seriesInfo['episode'])
        else:
            print('playing movie')
            driver.find_element_by_css_selector(".playLink").click()
    except Exception as ex:
        if(ex.__class__.__name__ == 'NoSuchElementException'):
            print(ex)
            driver.find_element_by_css_selector(".playLink").click()
            
    print('moving to last')
    moveToLast()

# %%
import csv
showList = []
with open('./NetflixViewingHistory.csv', newline='') as csvfile:
#     spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
#     for row, index in spamreader:
#         print(row)
     reader = csv.DictReader(csvfile)
     for row in reader:
        showList.append(row['Title'])

# %%
for showFullName in reversed(showList):
    performAction(showFullName)
# Out:
# ['The Witcher', '1: The End’s Beginning']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'The End’s Beginning'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['Lucifer', '1: Pilot']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Pilot'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Lucifer, Stay. Good Devil.']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Lucifer, Stay. Good Devil.'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: The Would-Be Prince of Darkness']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'The Would-Be Prince of Darkness'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Manly Whatnots']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Manly Whatnots'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Sweet Kicks']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Sweet Kicks'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Favorite Son']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Favorite Son'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Et Tu, Doctor?']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Et Tu, Doctor?'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: A Priest Walks into a Bar']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'A Priest Walks into a Bar'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Pops']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Pops'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: St. Lucifer']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'St. Lucifer'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: #TeamLucifer']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': '#TeamLucifer'}
# Season 1 Season 1
# moving to last
# ['Lucifer', '1: Take Me Back to Hell']
# Lucifer {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Take Me Back to Hell'}
# Season 1 Season 1
# moving to last
# ['Lucifer', "2: Everything's Coming Up Lucifer"]
# Lucifer {'seasonInfo': 'Season 2', 'season': 2, 'episode': "Everything's Coming Up Lucifer"}
# Season 1 Season 2
# moving to last
# ['The Witcher', '1: Four Marks']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Four Marks'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['The Witcher', '1: Betrayer Moon']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Betrayer Moon'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['The Witcher', '1: Of Banquets, Bastards and Burials']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Of Banquets, Bastards and Burials'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['The Witcher', '1: Bottled Appetites']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Bottled Appetites'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['The Witcher', '1: Rare Species']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Rare Species'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['The Witcher', '1: Before a Fall']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Before a Fall'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['The Witcher', '1: Much More']
# The Witcher {'seasonInfo': 'Season 1', 'season': 1, 'episode': 'Much More'}
# Message: no such element: Unable to locate element: {"method":"css selector","selector":".dropdown-toggle"}
#   (Session info: chrome=86.0.4240.111)
#
# moving to last
# ['Money Heist', '1: Episode 1']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 1'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 2']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 2'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 3']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 3'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 4']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 4'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 5']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 5'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 6']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 6'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 7']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 7'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 8']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 8'}
# Part 1 Part 1
# moving to last
# ['Money Heist', '1: Episode 9']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 9'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 10']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 10'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 11']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 11'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 12']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 12'}
#  Part 1
# moving to last
# ['Money Heist', '1: Episode 13']
# Money Heist {'seasonInfo': 'Part 1', 'season': 1, 'episode': 'Episode 13'}
#  Part 1
# moving to last
# ['Money Heist', '2: Episode 1']
# Money Heist {'seasonInfo': 'Part 2', 'season': 2, 'episode': 'Episode 1'}
#  Part 2
# moving to last
# ['Money Heist', '2: Episode 2']
# Money Heist {'seasonInfo': 'Part 2', 'season': 2, 'episode': 'Episode 2'}
#  Part 2
# moving to last
# ['Money Heist', '2: Episode 3']
# Money Heist {'seasonInfo': 'Part 2', 'season': 2, 'episode': 'Episode 3'}
#  Part 2
# moving to last
# ['Money Heist', '2: Episode 4']
# Money Heist {'seasonInfo': 'Part 2', 'season': 2, 'episode': 'Episode 4'}
#  Part 2
# moving to last

# %%
# driver.close()
